# %%
import pandas as pd

# %%
# renombrar fuente de datos

# %%
creditcp = pd.read_csv('./../data/application_record.csv')

# %%
# mostar encabezado de datos

# %%
creditcp.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# ...

# %%
# observar forma de los datos

# %%
creditcp.shape
# Out:
# (438557, 18)

# %%
# observar tipo de datos por variable
creditcp.dtypes
# Out:
# ID                       int64
# CODE_GENDER             object
# FLAG_OWN_CAR            object
# FLAG_OWN_REALTY         object
# CNT_CHILDREN             int64
# AMT_INCOME_TOTAL       float64
# NAME_INCOME_TYPE        object
# NAME_EDUCATION_TYPE     object
# NAME_FAMILY_STATUS      object
# NAME_HOUSING_TYPE       object
# DAYS_BIRTH               int64
# DAYS_EMPLOYED            int64
# FLAG_MOBIL               int64
# FLAG_WORK_PHONE          int64
# FLAG_PHONE               int64
# FLAG_EMAIL               int64
# OCCUPATION_TYPE         object
# CNT_FAM_MEMBERS        float64
# dtype: object

# %% [markdown]
# # Preguntas

# %%
# cuál es el ingreso máximo y mínimo?
# cuál es el ingreso promedio?
# cómo es la distribución de los ingresos?
# qué género tiene mayores ingresos?
# cuál es el empleo que da mayores ingresos?
# cuál es el empleo más común?
# cual es el nivel de educación que más se presenta?
# qué porcentaje de clientes cuenta con un carro?
# qué porcentaje de clientes cuenta con una propiedad?

# %%
# cuál es el ingreso máximo y mínimo?
print('maximo: ', creditcp['AMT_INCOME_TOTAL'].max())
print('minimo: ', creditcp['AMT_INCOME_TOTAL'].min())
# Out:
# maximo:  6750000.0
# minimo:  26100.0

# %%
# cual es el ingreso promedio?
creditcp['AMT_INCOME_TOTAL'].mean()
# Out:
# 187524.28600950394

# %%
# como es la distribución de los ingresos?
creditcp['AMT_INCOME_TOTAL'].hist(bins=150)
# Out:
# <AxesSubplot:>

# %%
# que genero tiene mayores ingresos?

# %%
# cual es el empleo que da mayores ingresos?
creditcp[(creditcp['AMT_INCOME_TOTAL']=='max()')]
# Out:
# Empty DataFrame
# Columns: [ID, CODE_GENDER, FLAG_OWN_CAR, FLAG_OWN_REALTY, CNT_CHILDREN, AMT_INCOME_TOTAL, NAME_INCOME_TYPE, NAME_EDUCATION_TYPE, NAME_FAMILY_STATUS, NAME_HOUSING_TYPE, DAYS_BIRTH, DAYS_EMPLOYED, FLAG_MOBIL, FLAG_WORK_PHONE, FLAG_PHONE, FLAG_EMAIL, OCCUPATION_TYPE, CNT_FAM_MEMBERS]
# Index: []

# %%
# cuál es el empleo más común?
creditcp['OCCUPATION_TYPE'].value_counts()
# Out:
# Laborers                 78240
# Core staff               43007
# Sales staff              41098
# Managers                 35487
# Drivers                  26090
# High skill tech staff    17289
# Accountants              15985
# Medicine staff           13520
# Cooking staff             8076
# Security staff            7993
# Cleaning staff            5845
# Private service staff     3456
# Low-skill Laborers        2140
# Secretaries               2044
# Waiters/barmen staff      1665
# Realty agents             1041
# HR staff                   774
# IT staff                   604
# Name: OCCUPATION_TYPE, dtype: int64

# %%
# cual es el nivel de educación que más se presenta?
creditcp['NAME_EDUCATION_TYPE'].value_counts()
# Out:
# Secondary / secondary special    301821
# Higher education                 117522
# Incomplete higher                 14851
# Lower secondary                    4051
# Academic degree                     312
# Name: NAME_EDUCATION_TYPE, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
education_df=creditcp.groupby(['NAME_EDUCATION_TYPE']).count().reset_index()
education_df
# Out:
#              NAME_EDUCATION_TYPE      ID  CODE_GENDER  FLAG_OWN_CAR  \
# 0                Academic degree     312          312           312
# 1               Higher education  117522       117522        117522
# 2              Incomplete higher   14851        14851         14851
# 3                Lower secondary    4051         4051          4051
# 4  Secondary / secondary special  301821       301821        301821
#
#    FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  NAME_INCOME_TYPE  \
# 0              312           312               312               312
# 1           117522        117522            117522            117522
# 2            14851         14851             14851             14851
# 3             4051          4051              4051              4051
# 4           301821        301821            301821            301821
#
#    NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0                 312                312         312            312
# ...

# %%
plt.barh(education_df['NAME_EDUCATION_TYPE'], education_df['CODE_GENDER'])
plt.show()

# %%
# qué porcentaje de clientes cuenta con un carro?
creditcp['FLAG_OWN_CAR'].value_counts()
# Out:
# N    275459
# Y    163098
# Name: FLAG_OWN_CAR, dtype: int64

# %%
creditcp[(creditcp['FLAG_OWN_CAR']=='Y')]
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 10      5008815           M            Y               Y             0
# 11      5112956           M            Y               Y             0
# ...         ...         ...          ...             ...           ...
# 438519  6836039           M            Y               N             0
# 438539  6837454           M            Y               Y             1
# 438542  6837905           M            Y               Y             1
# 438543  6837906           M            Y               Y             1
# 438548  6839936           M            Y               Y             1
#
#         AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
print('El porcentaje de clientes con carro es: ')
# Out:
# El porcentaje de clientes con carro es:

# %%
# qué porcentaje de clientes cuenta con una propiedad?
creditcp['FLAG_OWN_REALTY'].value_counts()
# Out:
# Y    304074
# N    134483
# Name: FLAG_OWN_REALTY, dtype: int64

# %%
creditcp[(creditcp['FLAG_OWN_REALTY']=='Y')]
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438550  6840100           F            N               Y             0
# 438551  6840102           F            N               Y             0
# 438552  6840104           M            N               Y             0
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...
